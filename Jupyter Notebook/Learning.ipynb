# %%
import sys, sysconfig
print(sys.executable)          # should point to .venv\Scripts\python.exe
print(sys.prefix)              # should point to your .venv directory
# Out:
# D:\Python JupyterNB Learning\Jupyter Notebook\.venv\Scripts\python.exe
# D:\Python JupyterNB Learning\Jupyter Notebook\.venv

# %%
import pyjokes
print(pyjokes.__file__)        # should be under .venv\Lib\site-packages if installed in venv
# Out:
# d:\Python JupyterNB Learning\Jupyter Notebook\.venv\Lib\site-packages\pyjokes\__init__.py
